# %%
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDRegressor
from sklearn.datasets import load_diabetes
from sklearn.metrics import r2_score

# %%
X,y=load_diabetes(return_X_y=True)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
y_train.shape
# Out:
# (353,)

# %%
class SGD_Regressor: 
    def __init__(self,learning_rate=0.5,epoch=25):
        self.coef_=None
        self.intercept_=None
        self.lr=learning_rate
        self.epoch=epoch

    def fit(self,X_train,y_train):
        self.intercept_=0                           
        self.coef_=np.ones(X_train.shape[1])
        for i in range(self.epoch):
            for j in range(X_train.shape[0]):

                idx=np.random.randint(0,X_train.shape[0])

                y_hat=np.dot(X_train[idx],self.coef_)+self.intercept_
                intercept_der=-2*(y_train[idx]-y_hat)
                self.intercept_=self.intercept_-self.lr*intercept_der
                coef_der=-2*(y_train[idx]-y_hat)*X_train[idx]
                self.coef_=self.coef_-self.lr*coef_der
    def predict(self,X_test):
            return np.dot(X_train,self.coef_)+self.intercept_

# %%
model=SGD_Regressor(0.10)

# %%
model.fit(X_train,y_train)

# %%
y_pred=model.predict(X_test)

# %%
X_test.shape
# Out:
# (89, 10)

# %%
y_test.shape
# Out:
# (89,)

# %%
y_pred=y_pred[0:89]

# %%
y_pred
# Out:
# array([ 68.86644339, 148.60965858,  53.01348059, 181.50914653,
#         72.14754102, 133.59088492, 252.60249958, 144.23488023,
#        181.08649584, 152.5032876 , 158.31714667, 106.55447525,
#        127.35493329,  92.36007527, 164.34126832, 142.73125569,
#        173.28564061, 103.25802592, 135.66967615, 167.09052498,
#        134.13710295, 226.78820341, 169.95158375, 230.98751681,
#        157.97871645,  65.6849095 , 102.02778926,  65.03754014,
#        143.09579798, 186.08741446,  70.01377196, 191.57043296,
#        258.12431664, 167.64427541, 190.87528989, 256.91646171,
#        189.35558459, 157.94275631,  53.46403964, 162.49605251,
#         42.43081324, 118.4727787 ,  86.4246859 ,  99.27619189,
#        149.38980276,  39.66008107, 106.94781689, 149.67434756,
#        134.47589141, 168.32297965, 212.34639235, 279.82281266,
#        174.64814367, 136.11047918, 132.28850347, 112.56764679,
#        122.59542311, 103.91451598, 156.62788453,  73.609964  ,
#        252.80294206,  88.37177134, 179.58559749,  84.11485978,
#        219.94330833, 145.54558543, 222.02800562, 118.56559113,
#         57.45627943,  83.07445174,  80.04998434, 120.9833443 ,
#        258.61182233, 101.63299784, 141.98626804, 163.41179755,
#         82.58100675, 184.64987916,  83.51654772, 102.47254555,
#        217.04720098, 207.65391196, 220.64980655, 118.2299718 ,
#        152.9685566 , 115.88498214,  91.06157265, 101.56150164,
#        166.27399717])

# %%
r2_score(y_test,y_pred)
# Out:
# -0.8162914113048811

# %%
model1.fit(X_train,y_train)
# Out:
# SGDRegressor(alpha=0.01, max_iter=677700)

# %%
y_pred=model1.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.27831717641851095
