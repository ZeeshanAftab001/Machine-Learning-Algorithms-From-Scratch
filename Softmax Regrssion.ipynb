# %%
from sklearn.linear_model import LogisticRegression

# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
import seaborn as sns 
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.datasets import load_breast_cancer

# %%
df=load_breast_cancer(return_X_y=True,as_frame=True)

# %%
encoder=LabelEncoder()

# %%
df['species']=encoder.fit_transform(df['species'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df['species']=encoder.fit_transform(df['species'])
#
# TypeError: tuple indices must be integers or slices, not str

# %%
X=df.iloc[:,0:4]

# %%
y=df.iloc[:,4]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
X_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 73            6.1          2.8           4.7          1.2
# 18            5.7          3.8           1.7          0.3
# 118           7.7          2.6           6.9          2.3
# 78            6.0          2.9           4.5          1.5
# 76            6.8          2.8           4.8          1.4
# 31            5.4          3.4           1.5          0.4
# 64            5.6          2.9           3.6          1.3
# 141           6.9          3.1           5.1          2.3
# 68            6.2          2.2           4.5          1.5
# 82            5.8          2.7           3.9          1.2
# 110           6.5          3.2           5.1          2.0
# 12            4.8          3.0           1.4          0.1
# 36            5.5          3.5           1.3          0.2
# 9             4.9          3.1           1.5          0.1
# 19            5.1          3.8           1.5          0.3
# 56            6.3          3.3           4.7          1.6
# 104           6.5          3.0           5.8          2.2
# 69            5.6          2.5           3.9          1.1
# 55            5.7          2.8           4.5          1.3
# 132           6.4          2.8           5.6          2.2
# 29            4.7          3.2           1.6          0.2
# 127           6.1          3.0           4.9          1.8
# 26            5.0          3.4           1.6          0.4
# 128           6.4          2.8           5.6          2.1
# 131           7.9          3.8           6.4          2.0
# 145           6.7          3.0           5.2          2.3
# 108           6.7          2.5           5.8          1.8
# 143           6.8          3.2           5.9          2.3
# 45            4.8          3.0           1.4          0.3
# 30            4.8          3.1           1.6          0.2

# %%
model=LogisticRegression(multi_class='multinomial')

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(multi_class='multinomial')

# %%
y_pred=model.predict(X_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
x=np.array([[2,4,5,4],[3,6,7,6]])
y=np.array([[2],[2]])

# %%
d=model.predict(x)
# Out:
# C:\Users\Zeeshan Aftab\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
accuracy_score(y,d)
# Out:
# 1.0
